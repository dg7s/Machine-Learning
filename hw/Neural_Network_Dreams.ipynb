# %% [markdown]
# # Lab 9 - Multi Layer Perceptron, MLP
#
# Dominik Gaweł
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dg7s/Machine-Learning/blob/main/hw/Neural_Network_Dreams.ipynb)
# -------------------------------

# %% [markdown]
# # **Homework Assignment - *Do Androids Dream of Electric Sheep?***
#
# -------------------------------------
#
# "Do Androids Dream of Electric Sheep?" – the famous title of Philip K. Dick’s novel – raises a fascinating question: if artificial intelligence could dream, what would it see?
#
# In this assignment, we explore a phenomenon known as **neural network dreams**, where instead of optimizing a neural network's weights, we **optimize the input itself** to achieve a desired classification outcome. Given a fully trained MNIST classification network, your goal is to manipulate its inputs so that it confidently predicts each digit from 0 to 9, starting from pure noise.
#
# ## **Tasks Description**
#
# During this class we designed and trained a **MNIST classification neural network**, which takes a **batch of grayscale images** of size **$28 \times 28$** as input and outputs a probability distribution over the 10 digit classes (0–9). However, instead of using real MNIST images, you will **treat the input batch itself as a set of trainable parameters** and optimize it so that the network classifies each image as a specific digit.
#
# 1. Your first task is to generate **a batch of 10 images**, where each image is
#    classified as one of the digits **0, 1, 2, ..., 9**, starting from an initial batch of ten random Gaussian noise images.
#
#    Discuss the following question: do the generated images resemble real MNIST digits? Why or why not?
#
# 2. Discuss, how you would approach a second task of
#    generating an image that
#    bares similarity to two or more digits simultaneously. **Implement your idea to see the results.**
#
# 3. Third task: repeat the previous tasks with an additional L2 penalty on noise within the images. Experiment with adding `lambda_l2 * dreamed_input_batch.pow(2).mean()` loss term, with `lambda_l2` being the penalty cooefficient within an exponential progression, say from 0.001 to 10.0. Are the new digits recognized correctly? How does the penalty impact the digit quality? Explain.
#
# ### **Optimization Process for Task 1**
#
# 1. Start with a **batch of 10 random Gaussian noise images** as the initial input and $(0, 1, 2, \ldots, 9)$ as the expected output batch of target digits.
# 2. Define the objective: maximize the neural network's confidence for the corresponding target digit for each image in the batch.
# 3. Use **gradient descent** to modify the pixels in each image, making the network classify each one as the assigned digit.
# 4. Repeat until the network assigns suffieciently high confidence to each image’s target class.
#
# ### **Implementation Details**
#
# - The neural network weights **must remain frozen** during optimization. You are modifying only the input images.
# - The loss function should be the **cross-entropy loss** between the predicted probabilities and the desired class labels (plus an optional weighted L2 penalty regularizing the images in task 3).
#
#
# ## **Points to Note**
#
# 1. **Visualize** the optimization process: Save images of the generated inputs at different steps and plot the classification confidence evolution over iterations.
# 3. **Document your findings** and explain the behavior you observe.
#
# ## **Task & Deliverables**
#
# - A **Colab notebook** containing solutions for both tasks:
#   - The full implementation.
#   - Visualizations of the generated batch of images.
#   - A written explanation of your observations.
# - **Bonus:** If you create an **animation** showing the evolution of the input images during optimization, it will be considered a strong enhancement to your submission.
#   - You can generate an animation programmatically (e.g., using Matplotlib or OpenCV).
#   - Or, save image frames and use external tools to create a video.
#   - Provide a **link** to any video files in the README.
# - Upload your notebook and results to your **GitHub repository** for the course.
# - In the **README**, include a **link** to the notebook.
# - In the notebook, include **“Open in Colab”** badge so it can be launched directly.

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import torch.nn.functional as F
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import random

# %%
SEED = 42
torch.manual_seed(SEED)
random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
transform = torchvision.transforms.Compose(
    [ torchvision.transforms.ToTensor(),
      torchvision.transforms.Normalize((0.1307), (0.3081))])

trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=2048,
                                          shuffle=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:02<00:00, 4.59MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.09MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.81MB/s]

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.mlp = torch.nn.Sequential(
            torch.nn.Flatten(),
            torch.nn.Linear(1*28*28, 1024),
            torch.nn.ReLU(),
            torch.nn.Linear(1024, 2048),
            torch.nn.ReLU(),
            torch.nn.Linear(2048, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 10),
        )
        self.dropout = torch.nn.Dropout(0.05)

    def forward(self, x):
        x = self.mlp(x)
        x = self.dropout(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Working on {device}")

net = MLP().to(device)
optimizer = torch.optim.Adam(net.parameters(), 0.001)

net.train()
for epoch in range(8):

    loss = 0.0
    for batch, data in enumerate(trainloader):
        batch_inputs, batch_labels = data

        batch_inputs = batch_inputs.to(device)
        batch_labels = batch_labels.to(device)

        optimizer.zero_grad()

        batch_outputs = net(batch_inputs)
        loss = torch.nn.functional.cross_entropy(batch_outputs, batch_labels, reduction = "mean")
        print("epoch:", epoch, "batch:", batch, "current batch loss:", loss.item())
        loss.backward()
        optimizer.step()
# Out:
# Working on cuda
# epoch: 0 batch: 0 current batch loss: 2.310203790664673
# epoch: 0 batch: 1 current batch loss: 2.0768327713012695
# epoch: 0 batch: 2 current batch loss: 1.624901294708252
# epoch: 0 batch: 3 current batch loss: 1.1932710409164429
# epoch: 0 batch: 4 current batch loss: 1.1437439918518066
# epoch: 0 batch: 5 current batch loss: 0.9622821807861328
# epoch: 0 batch: 6 current batch loss: 0.9507745504379272
# epoch: 0 batch: 7 current batch loss: 0.8162147998809814
# epoch: 0 batch: 8 current batch loss: 0.7120282053947449
# epoch: 0 batch: 9 current batch loss: 0.6511026620864868
# epoch: 0 batch: 10 current batch loss: 0.6360457539558411
# epoch: 0 batch: 11 current batch loss: 0.6028648018836975
# epoch: 0 batch: 12 current batch loss: 0.5230752825737
# epoch: 0 batch: 13 current batch loss: 0.5151314735412598
# epoch: 0 batch: 14 current batch loss: 0.4442121982574463
# epoch: 0 batch: 15 current batch loss: 0.4606562554836273
# epoch: 0 batch: 16 current batch loss: 0.46927446126937866
# epoch: 0 batch: 17 current batch loss: 0.43386879563331604
# epoch: 0 batch: 18 current batch loss: 0.3540883958339691
# epoch: 0 batch: 19 current batch loss: 0.35547706484794617
# epoch: 0 batch: 20 current batch loss: 0.36830615997314453
# epoch: 0 batch: 21 current batch loss: 0.37946659326553345
# epoch: 0 batch: 22 current batch loss: 0.3558649718761444
# epoch: 0 batch: 23 current batch loss: 0.304450660943985
# epoch: 0 batch: 24 current batch loss: 0.3457763195037842
# epoch: 0 batch: 25 current batch loss: 0.2910933196544647
# epoch: 0 batch: 26 current batch loss: 0.34030288457870483
# epoch: 0 batch: 27 current batch loss: 0.3225764036178589
# epoch: 0 batch: 28 current batch loss: 0.28727152943611145
# epoch: 0 batch: 29 current batch loss: 0.3031998872756958
# epoch: 1 batch: 0 current batch loss: 0.28804653882980347
# epoch: 1 batch: 1 current batch loss: 0.2634483277797699
# epoch: 1 batch: 2 current batch loss: 0.20396173000335693
# epoch: 1 batch: 3 current batch loss: 0.2594671845436096
# epoch: 1 batch: 4 current batch loss: 0.25085899233818054
# epoch: 1 batch: 5 current batch loss: 0.2711835205554962
# epoch: 1 batch: 6 current batch loss: 0.2257171869277954
# epoch: 1 batch: 7 current batch loss: 0.20700770616531372
# epoch: 1 batch: 8 current batch loss: 0.22907917201519012
# epoch: 1 batch: 9 current batch loss: 0.19570057094097137
# epoch: 1 batch: 10 current batch loss: 0.2222553789615631
# epoch: 1 batch: 11 current batch loss: 0.20573419332504272
# epoch: 1 batch: 12 current batch loss: 0.22966593503952026
# epoch: 1 batch: 13 current batch loss: 0.22261501848697662
# epoch: 1 batch: 14 current batch loss: 0.19641883671283722
# epoch: 1 batch: 15 current batch loss: 0.21006861329078674
# epoch: 1 batch: 16 current batch loss: 0.188386008143425
# epoch: 1 batch: 17 current batch loss: 0.19660378992557526
# epoch: 1 batch: 18 current batch loss: 0.17123231291770935
# epoch: 1 batch: 19 current batch loss: 0.19041335582733154
# epoch: 1 batch: 20 current batch loss: 0.16610699892044067
# epoch: 1 batch: 21 current batch loss: 0.17036813497543335
# epoch: 1 batch: 22 current batch loss: 0.1801830530166626
# epoch: 1 batch: 23 current batch loss: 0.13277438282966614
# epoch: 1 batch: 24 current batch loss: 0.16797196865081787
# epoch: 1 batch: 25 current batch loss: 0.16952592134475708
# epoch: 1 batch: 26 current batch loss: 0.1534191519021988
# epoch: 1 batch: 27 current batch loss: 0.16741882264614105
# epoch: 1 batch: 28 current batch loss: 0.15967102348804474
# epoch: 1 batch: 29 current batch loss: 0.13845784962177277
# epoch: 2 batch: 0 current batch loss: 0.14790765941143036
# epoch: 2 batch: 1 current batch loss: 0.13221901655197144
# epoch: 2 batch: 2 current batch loss: 0.14869937300682068
# epoch: 2 batch: 3 current batch loss: 0.12539894878864288
# epoch: 2 batch: 4 current batch loss: 0.1566491723060608
# epoch: 2 batch: 5 current batch loss: 0.14669249951839447
# epoch: 2 batch: 6 current batch loss: 0.1266603022813797
# epoch: 2 batch: 7 current batch loss: 0.12056419998407364
# epoch: 2 batch: 8 current batch loss: 0.11246363818645477
# epoch: 2 batch: 9 current batch loss: 0.15254230797290802
# epoch: 2 batch: 10 current batch loss: 0.12082833051681519
# epoch: 2 batch: 11 current batch loss: 0.13375145196914673
# epoch: 2 batch: 12 current batch loss: 0.10636698454618454
# epoch: 2 batch: 13 current batch loss: 0.13903899490833282
# epoch: 2 batch: 14 current batch loss: 0.13349729776382446
# epoch: 2 batch: 15 current batch loss: 0.13288052380084991
# epoch: 2 batch: 16 current batch loss: 0.11828238517045975
# epoch: 2 batch: 17 current batch loss: 0.1090906634926796
# epoch: 2 batch: 18 current batch loss: 0.12244383990764618
# epoch: 2 batch: 19 current batch loss: 0.13032662868499756
# epoch: 2 batch: 20 current batch loss: 0.1167948916554451
# epoch: 2 batch: 21 current batch loss: 0.12249459326267242
# epoch: 2 batch: 22 current batch loss: 0.11197593063116074
# epoch: 2 batch: 23 current batch loss: 0.11401394754648209
# epoch: 2 batch: 24 current batch loss: 0.11441678553819656
# epoch: 2 batch: 25 current batch loss: 0.11182467639446259
# epoch: 2 batch: 26 current batch loss: 0.11217992752790451
# epoch: 2 batch: 27 current batch loss: 0.112816721200943
# epoch: 2 batch: 28 current batch loss: 0.1100437343120575
# epoch: 2 batch: 29 current batch loss: 0.13185009360313416
# epoch: 3 batch: 0 current batch loss: 0.0953923836350441
# epoch: 3 batch: 1 current batch loss: 0.08927123993635178
# epoch: 3 batch: 2 current batch loss: 0.0977766215801239
# epoch: 3 batch: 3 current batch loss: 0.0936991274356842
# epoch: 3 batch: 4 current batch loss: 0.11070884019136429
# epoch: 3 batch: 5 current batch loss: 0.10728409886360168
# epoch: 3 batch: 6 current batch loss: 0.10103929042816162
# epoch: 3 batch: 7 current batch loss: 0.1102796122431755
# epoch: 3 batch: 8 current batch loss: 0.08827701210975647
# epoch: 3 batch: 9 current batch loss: 0.09070529788732529
# epoch: 3 batch: 10 current batch loss: 0.0897957980632782
# epoch: 3 batch: 11 current batch loss: 0.0919119343161583
# epoch: 3 batch: 12 current batch loss: 0.1015603244304657
# epoch: 3 batch: 13 current batch loss: 0.10190098732709885
# epoch: 3 batch: 14 current batch loss: 0.10259808599948883
# epoch: 3 batch: 15 current batch loss: 0.10800240188837051
# epoch: 3 batch: 16 current batch loss: 0.09597842395305634
# epoch: 3 batch: 17 current batch loss: 0.0964427962899208
# epoch: 3 batch: 18 current batch loss: 0.08906949311494827
# epoch: 3 batch: 19 current batch loss: 0.09953565150499344
# epoch: 3 batch: 20 current batch loss: 0.08047669380903244
# epoch: 3 batch: 21 current batch loss: 0.08688123524188995
# epoch: 3 batch: 22 current batch loss: 0.10429266095161438
# epoch: 3 batch: 23 current batch loss: 0.08159396797418594
# epoch: 3 batch: 24 current batch loss: 0.07765596359968185
# epoch: 3 batch: 25 current batch loss: 0.08004173636436462
# epoch: 3 batch: 26 current batch loss: 0.09065279364585876
# epoch: 3 batch: 27 current batch loss: 0.07361308485269547
# epoch: 3 batch: 28 current batch loss: 0.09527170658111572
# epoch: 3 batch: 29 current batch loss: 0.08385614305734634
# epoch: 4 batch: 0 current batch loss: 0.07604145258665085
# epoch: 4 batch: 1 current batch loss: 0.07255971431732178
# epoch: 4 batch: 2 current batch loss: 0.07214198261499405
# epoch: 4 batch: 3 current batch loss: 0.07838517427444458
# epoch: 4 batch: 4 current batch loss: 0.07430735975503922
# epoch: 4 batch: 5 current batch loss: 0.08649007976055145
# epoch: 4 batch: 6 current batch loss: 0.06740608811378479
# epoch: 4 batch: 7 current batch loss: 0.06216249614953995
# epoch: 4 batch: 8 current batch loss: 0.06671826541423798
# epoch: 4 batch: 9 current batch loss: 0.07828919589519501
# epoch: 4 batch: 10 current batch loss: 0.07748473435640335
# epoch: 4 batch: 11 current batch loss: 0.06521047651767731
# epoch: 4 batch: 12 current batch loss: 0.06895557045936584
# epoch: 4 batch: 13 current batch loss: 0.06344585120677948
# epoch: 4 batch: 14 current batch loss: 0.08462677896022797
# epoch: 4 batch: 15 current batch loss: 0.05725247040390968
# epoch: 4 batch: 16 current batch loss: 0.0681648775935173
# epoch: 4 batch: 17 current batch loss: 0.07555598765611649
# epoch: 4 batch: 18 current batch loss: 0.05906742438673973
# epoch: 4 batch: 19 current batch loss: 0.0796661376953125
# epoch: 4 batch: 20 current batch loss: 0.08035058528184891
# epoch: 4 batch: 21 current batch loss: 0.05318824574351311
# epoch: 4 batch: 22 current batch loss: 0.0686347484588623
# epoch: 4 batch: 23 current batch loss: 0.07059144973754883
# epoch: 4 batch: 24 current batch loss: 0.07559077441692352
# epoch: 4 batch: 25 current batch loss: 0.06173594295978546
# epoch: 4 batch: 26 current batch loss: 0.05389903858304024
# epoch: 4 batch: 27 current batch loss: 0.08343593031167984
# epoch: 4 batch: 28 current batch loss: 0.08213196694850922
# epoch: 4 batch: 29 current batch loss: 0.09448399394750595
# epoch: 5 batch: 0 current batch loss: 0.05498816817998886
# epoch: 5 batch: 1 current batch loss: 0.055070023983716965
# epoch: 5 batch: 2 current batch loss: 0.06348513066768646
# epoch: 5 batch: 3 current batch loss: 0.06431548297405243
# epoch: 5 batch: 4 current batch loss: 0.05689220875501633
# epoch: 5 batch: 5 current batch loss: 0.05389079451560974
# epoch: 5 batch: 6 current batch loss: 0.07335539162158966
# epoch: 5 batch: 7 current batch loss: 0.05129464343190193
# epoch: 5 batch: 8 current batch loss: 0.06232386454939842
# epoch: 5 batch: 9 current batch loss: 0.05712305009365082
# epoch: 5 batch: 10 current batch loss: 0.06582153588533401
# epoch: 5 batch: 11 current batch loss: 0.06479597091674805
# epoch: 5 batch: 12 current batch loss: 0.057648856192827225
# epoch: 5 batch: 13 current batch loss: 0.05927278473973274
# epoch: 5 batch: 14 current batch loss: 0.06472180038690567
# epoch: 5 batch: 15 current batch loss: 0.05334848910570145
# epoch: 5 batch: 16 current batch loss: 0.07438366860151291
# epoch: 5 batch: 17 current batch loss: 0.05658581480383873
# epoch: 5 batch: 18 current batch loss: 0.04375940188765526
# epoch: 5 batch: 19 current batch loss: 0.05182775855064392
# epoch: 5 batch: 20 current batch loss: 0.06261218339204788
# epoch: 5 batch: 21 current batch loss: 0.05163745954632759
# epoch: 5 batch: 22 current batch loss: 0.060956086963415146
# epoch: 5 batch: 23 current batch loss: 0.0706702172756195
# epoch: 5 batch: 24 current batch loss: 0.045313287526369095
# epoch: 5 batch: 25 current batch loss: 0.0731891468167305
# epoch: 5 batch: 26 current batch loss: 0.05499161034822464
# epoch: 5 batch: 27 current batch loss: 0.05930605158209801
# epoch: 5 batch: 28 current batch loss: 0.050262536853551865
# epoch: 5 batch: 29 current batch loss: 0.07715996354818344
# epoch: 6 batch: 0 current batch loss: 0.04700891301035881
# epoch: 6 batch: 1 current batch loss: 0.050585199147462845
# epoch: 6 batch: 2 current batch loss: 0.05502641201019287
# epoch: 6 batch: 3 current batch loss: 0.06709161400794983
# epoch: 6 batch: 4 current batch loss: 0.05661593750119209
# epoch: 6 batch: 5 current batch loss: 0.06568687409162521
# epoch: 6 batch: 6 current batch loss: 0.05632040649652481
# epoch: 6 batch: 7 current batch loss: 0.06363758444786072
# epoch: 6 batch: 8 current batch loss: 0.056032195687294006
# epoch: 6 batch: 9 current batch loss: 0.061197429895401
# epoch: 6 batch: 10 current batch loss: 0.04581258445978165
# epoch: 6 batch: 11 current batch loss: 0.04377308860421181
# epoch: 6 batch: 12 current batch loss: 0.05833250284194946
# epoch: 6 batch: 13 current batch loss: 0.052888669073581696
# epoch: 6 batch: 14 current batch loss: 0.058736152946949005
# epoch: 6 batch: 15 current batch loss: 0.04902917891740799
# epoch: 6 batch: 16 current batch loss: 0.041407398879528046
# epoch: 6 batch: 17 current batch loss: 0.03982779383659363
# epoch: 6 batch: 18 current batch loss: 0.049459848552942276
# epoch: 6 batch: 19 current batch loss: 0.04987156391143799
# epoch: 6 batch: 20 current batch loss: 0.044296786189079285
# epoch: 6 batch: 21 current batch loss: 0.06699083745479584
# epoch: 6 batch: 22 current batch loss: 0.041014961898326874
# epoch: 6 batch: 23 current batch loss: 0.04905468970537186
# epoch: 6 batch: 24 current batch loss: 0.048674099147319794
# epoch: 6 batch: 25 current batch loss: 0.05505871772766113
# epoch: 6 batch: 26 current batch loss: 0.05282426252961159
# epoch: 6 batch: 27 current batch loss: 0.0518362820148468
# epoch: 6 batch: 28 current batch loss: 0.05500879883766174
# epoch: 6 batch: 29 current batch loss: 0.042734865099191666
# epoch: 7 batch: 0 current batch loss: 0.037001971155405045
# epoch: 7 batch: 1 current batch loss: 0.04141493886709213
# epoch: 7 batch: 2 current batch loss: 0.052818458527326584
# epoch: 7 batch: 3 current batch loss: 0.03504319489002228
# epoch: 7 batch: 4 current batch loss: 0.041377801448106766
# epoch: 7 batch: 5 current batch loss: 0.039904527366161346
# epoch: 7 batch: 6 current batch loss: 0.032335489988327026
# epoch: 7 batch: 7 current batch loss: 0.03577549383044243
# epoch: 7 batch: 8 current batch loss: 0.033806297928094864
# epoch: 7 batch: 9 current batch loss: 0.03800402954220772
# epoch: 7 batch: 10 current batch loss: 0.0425640307366848
# epoch: 7 batch: 11 current batch loss: 0.035366833209991455
# epoch: 7 batch: 12 current batch loss: 0.027400607243180275
# epoch: 7 batch: 13 current batch loss: 0.0342387892305851
# epoch: 7 batch: 14 current batch loss: 0.031196391209959984
# epoch: 7 batch: 15 current batch loss: 0.036500442773103714
# epoch: 7 batch: 16 current batch loss: 0.030515382066369057
# epoch: 7 batch: 17 current batch loss: 0.0447690486907959
# epoch: 7 batch: 18 current batch loss: 0.027799565345048904
# epoch: 7 batch: 19 current batch loss: 0.03779347613453865
# epoch: 7 batch: 20 current batch loss: 0.04204432666301727
# epoch: 7 batch: 21 current batch loss: 0.02628496289253235
# epoch: 7 batch: 22 current batch loss: 0.04229309409856796
# epoch: 7 batch: 23 current batch loss: 0.03479277715086937
# epoch: 7 batch: 24 current batch loss: 0.02986997552216053
# epoch: 7 batch: 25 current batch loss: 0.05035736411809921
# epoch: 7 batch: 26 current batch loss: 0.04246195778250694
# epoch: 7 batch: 27 current batch loss: 0.03898642212152481
# epoch: 7 batch: 28 current batch loss: 0.03505942225456238
# epoch: 7 batch: 29 current batch loss: 0.01993030123412609

# %% [markdown]
# ### Task 1

# %%
net.eval()
dream = torch.randn(10, 1, 28, 28, device=device, requires_grad=True)
targets = torch.arange(10, device=device)
optimizer = torch.optim.Adam([dream], lr=0.1)

fig, axes = plt.subplots(2, 5, figsize=(10, 5))
plt.tight_layout()

frame_images = []
frame_probs = []

for step in range(50):
    optimizer.zero_grad()
    logits = net(dream)
    loss = F.cross_entropy(logits, targets)
    loss.backward()
    optimizer.step()
    dream.data.clamp_(-1, +1)

    with torch.no_grad():
        imgs = dream.detach().cpu() * 0.3081 + 0.1307
        imgs = imgs.clamp(0, 1).numpy()
        probs = F.softmax(net(dream), dim=1).detach().cpu().numpy()

    frame_images.append(imgs)
    frame_probs.append(probs)

imshow_objects = []
text_objects = []
for idx, ax in enumerate(axes.flatten()):
    img = ax.imshow(frame_images[0][idx, 0], cmap='gray')
    txt = ax.set_title(f"{idx}: {frame_probs[0][idx, idx]*100:.1f}%")
    ax.axis('off')
    imshow_objects.append(img)
    text_objects.append(txt)

def update(frame):
    for idx in range(10):
        imshow_objects[idx].set_data(frame_images[frame][idx, 0])
        text_objects[idx].set_text(f"{idx}: {frame_probs[frame][idx, idx]*100:.1f}%")
    return imshow_objects + text_objects

ani = FuncAnimation(fig, update, frames=len(frame_images), interval=100, blit=True)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="1000" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
#  The optimized images don’t look like real MNIST samples. Because we used a plain MLP, each pixel is optimized independently. Spatial relationships aren’t preserved, so the global shape of a digit breaks down and only high-confidence noise patterns remain.
#
# ----

# %% [markdown]
# ### Task 2

# %%
def generate_hybrid_digit(class1, class2, steps=50, blend_ratio=0.5):
    img = torch.randn(1, 1, 28, 28, device=device, requires_grad=True)
    target = torch.zeros(10, device=device)
    target[class1] = blend_ratio
    target[class2] = 1 - blend_ratio

    optimizer = torch.optim.Adam([img], lr=0.1)
    frames = []
    prob_history = []

    for step in range(steps):
        optimizer.zero_grad()
        logits = net(img)
        probs = F.softmax(logits, dim=1)
        loss = F.kl_div(F.log_softmax(logits, dim=1), target.unsqueeze(0), reduction='batchmean')
        loss.backward()
        optimizer.step()
        img.data.clamp_(-1, +1)

        with torch.no_grad():
            denorm = img.detach().cpu() * 0.3081 + 0.1307
            frames.append(denorm.squeeze().numpy())
            prob_history.append(probs.detach().cpu().numpy())

    return frames, prob_history

hybrid_frames, prob_history = generate_hybrid_digit(3, 5)

fig, ax = plt.subplots()
plt.close()

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(hybrid_frames[0], cmap='gray')
ax.axis('off')
title = ax.set_title(f'Step 0\nP(3): {prob_history[0][0,3]:.2f}, P(5): {prob_history[0][0,5]:.2f}')

def update_hybrid(frame):
    im.set_array(hybrid_frames[frame])
    title.set_text(f'Step {frame}\nP(3): {prob_history[frame][0,3]:.2f}, P(5): {prob_history[frame][0,5]:.2f}')
    return [im, title]

ani = FuncAnimation(fig, update_hybrid, frames=len(hybrid_frames), interval=100, blit=True)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# We optimized the inputs so the network’s output splits 50 % for one target digit and 50 % for the other by averaging their cross-entropy losses. The resulting images are classified at about 48 % vs. 52 %, confirming the method works.
#
# ---

# %% [markdown]
# ### Task 3

# %%
initial_dream = torch.randn(10, 1, 28, 28, device=device)

def dream_with_l2_animated(initial_dream, lambda_l2, steps=200):
    dream = initial_dream.clone().detach().requires_grad_(True)
    net.eval()
    targets = torch.arange(10, device=device)

    optimizer = torch.optim.Adam([dream], lr=0.1)
    frames = []
    confidence_history = []

    for step in range(steps):
        optimizer.zero_grad()
        logits = net(dream)
        ce_loss = F.cross_entropy(logits, targets)
        l2_loss = lambda_l2 * dream.pow(2).mean()
        total_loss = ce_loss + l2_loss

        total_loss.backward()
        optimizer.step()
        dream.data.clamp_(-1, +1)

        if step % 10 == 0 or step == steps-1:
            with torch.no_grad():
                denorm = dream.detach().cpu() * 0.3081 + 0.1307
                denorm = denorm.clamp(0, 1).numpy()
                probs = F.softmax(net(dream), dim=1)
                confidences = probs[range(10), targets].detach().cpu().numpy()

            frames.append(denorm)
            confidence_history.append(confidences)

    fig, axes = plt.subplots(2, 5, figsize=(12, 5))
    fig.suptitle(f"λ = {lambda_l2}", fontsize=14, y=0.95)
    plt.subplots_adjust(top=0.85, hspace=0.3, wspace=0.3)
    plt.close()

    ims = []
    for i, ax in enumerate(axes.flatten()):
        im = ax.imshow(frames[0][i,0], cmap='gray', animated=True)
        ax.axis('off')
        ax.set_title(f"{i}\n", fontsize=10)
        ims.append(im)

    def update(frame):
        for i, im in enumerate(ims):
            im.set_array(frames[frame][i,0])
            axes.flatten()[i].set_title(f"{i}\n{confidence_history[frame][i]:.1%}", fontsize=10)
        return ims

    return FuncAnimation(fig, update, frames=len(frames), interval=100, blit=True)

lambdas = [0.001, 0.01, 0.1, 1.0, 10.0]

for l in lambdas:
    ani = dream_with_l2_animated(initial_dream, l)
    display(HTML(ani.to_html5_video()))
    plt.close()
# Out:
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# As  $\lambda$ increases, the images become progressively smoother but also more blurred. $L_2$ penalizes large pixel values equally, so the optimizer is forced to use only darker tones. All generated digits are still classified correctly, however, at $\lambda=10$ the network’s confidence never reaches $100\%$, instead stabilizing at about $98\%$. Only at $\lambda=10$ do the outputs for digits $0$ and $5$, despite their blurriness, actually resemble recognizable MNIST digits.
